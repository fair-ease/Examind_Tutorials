# %% [markdown]
# # OpenEO endpoint in Examind - Example - Http Requests
#
# By Quentin BIALOTA (Geomatys)
#
# Contact : quentin.bialota@geomatys.com

# %% [markdown]
# ---
#
# ### **/!\ WARNING**
# This initial implementation of openEO may contain bugs. Please let me know if you find any.
#
# In this tutorial we will use http requests to communicate with the examind openEO implementation.
#
# ---

# %% [markdown]
# **Prerequisites :**
# - Have an examind (via docker) running on your machine
# - Have imported sentinel-2 data in Examind (through the web ui http://localhost/8080/examind [login: admin / password: admin])
# - In examind, have created a WCS (in Web Services page) named `test` (for this part, and to import your data, you can follow this tutorial : [How do you retrieve the id of the data you want to use ?](./retrieve_data_id.md)
# - In examind, have created a WPS (in Web Services page) named `test` (you need to enable Versions `1.0.0` **AND** `2.0.0`)

# %%
# Imports (Execute this cell once)
import requests
import json
from requests.auth import HTTPBasicAuth
import matplotlib.pyplot as plt
import rasterio
from io import BytesIO
import os

# Set the server ip here (before the /examind), by default: localhost:8080
SERVER_IP = "http://localhost:8080"
OPENEO_SERVICE_ID = "test"

# %% [markdown]
# ### 1 - List openEO available processes
#
# The first step we can do is to request the list of processes available via examind's openEO endpoint.

# %%
URL = SERVER_IP + "/examind/WS/openeo/" + OPENEO_SERVICE_ID + "/processes"

r = requests.get(url = URL)

data = r.json()

# If you want to show the raw json output
# print(json.dumps(data, indent=2))

# Iterate over each process in the data
for process in data['processes']:
    print(f"ID: {process['id']}")

    print(f"Description: {process['description']}")

    print("Parameters:")
    for parameter in process['parameters']:
        print(f"- {parameter['name']} {parameter['schema']}")
        print(f"  Description: {parameter['description']}")
        if 'subtype' in parameter['schema'] and parameter['schema']['subtype'] is not None:
            print(f"  Subtype: {parameter['schema']['subtype']}")

    print("Returns:")
    if process['returns']['schema'] is not None:
        print(f"  Description: {process['returns']['description']}")
        print(f"  Type: {process['returns']['schema']['type']}")
        if 'subtype' in process['returns']['schema'] and process['returns']['schema']['subtype'] is not None:
            print(f"  Subtype: {process['returns']['schema']['subtype']}")

    print("\n")
# Out:
# ID: examind.sensor.correct.fieldname
# Description: Fill the sensor fields label.
# Parameters:
# - observation_provider_id [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Observation provider identifier.
# - sensor_id [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Sensor identifier (Optional).
# Returns:
#
#
# ID: examind.test.multiple.type
# Description: Test multiple types.
# Parameters:
# - double.array.input [{'type': ['ARRAY'], 'subtype': 'Real'}]
#   Description: Double array input.
# - double.prim.array.input [{'type': ['ARRAY'], 'subtype': 'Real'}]
#   Description: Double primitive array input.
# - double.multiple.input [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: Double multiple input.
# - integer.array.input [{'type': ['ARRAY'], 'subtype': 'Integer'}]
#   Description: Double array input.
# - integer.prim.array.input [{'type': ['ARRAY'], 'subtype': 'Integer'}]
#   Description: Integer primitive array input.
# - integer.multiple.input [{'type': ['INTEGER'], 'subtype': 'Integer'}]
#   Description: Integer multiple input.
# - long.array.input [{'type': ['ARRAY'], 'subtype': 'Integer'}]
#   Description: Long array input.
# - long.prim.array.input [{'type': ['ARRAY'], 'subtype': 'Integer'}]
#   Description: Long primitive array input.
# - long.multiple.input [{'type': ['INTEGER'], 'subtype': 'Integer'}]
#   Description: Long multiple input.
# - boolean.array.input [{'type': ['ARRAY'], 'subtype': 'Boolean'}]
#   Description: Boolean array input.
# - boolean.prim.array.input [{'type': ['ARRAY'], 'subtype': 'boolean'}]
#   Description: Boolean primitive array input.
# - boolean.multiple.input [{'type': ['BOOLEAN'], 'subtype': 'Boolean'}]
#   Description: Boolean multiple input.
# - char.array.input [{'type': ['ARRAY'], 'subtype': 'java.lang.Character'}]
#   Description: character array input.
# - char.prim.array.input [{'type': ['ARRAY'], 'subtype': 'char'}]
#   Description: Character primitive array input.
# - char.multiple.input [{'type': ['OBJECT'], 'subtype': 'java.lang.Character'}]
#   Description: Character multiple input.
# - file.input [{'type': ['OBJECT'], 'subtype': 'java.io.File'}]
#   Description: File input.
# - path.input [{'type': []}]
#   Description: Path input.
# Returns:
#   Description: Double array output.
#   Type: ['ARRAY']
#
#
# ID: examind.provider.restart
# Description: Restart a provider in Examind.
# Parameters:
# - provider_id [{'type': ['INTEGER'], 'subtype': 'Integer'}]
#   Description: Identifier of the provider.
# Returns:
#
#
# ID: examind.service.delete
# Description: Delete a service instance in Examind.
# Parameters:
# - service_type [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: The type of the service.
# - identifier [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Identifier of the new service instance.
# Returns:
#
#
# ID: examind.test.progress
# Description: Test the execution progress of a process.
# Parameters:
# Returns:
#
#
# ID: examind.test.parameter.group
# Description: Test parameter group in/out.
# Parameters:
# - in.test.group [{'type': []}]
#   Description: input groups
# Returns:
#   Description: output groups
#   Type: []
#
#
# ID: examind.test.nb_feature
# Description: Count the number of feature in a featureSet.
# Parameters:
# - featureset [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.storage.FeatureSet'}]
#   Description: The input featureSet.
# Returns:
#   Description: The number of feature in the featureSet.
#   Type: ['INTEGER']
#
#
# ID: examind.galaxy.deploy
# Description: Register a new workflow hosted by a galaxy server in examind
# Parameters:
# - galaxy.workflow.id [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: The galaxy workflow id (can be found in URL)
# - configuration [{'type': []}]
#   Description: A document describing the input / output of the workflow to deploy.
# Returns:
#   Description: The assigned identifier of the deployed workflow.
#   Type: ['STRING']
#
#
# ID: examind.service.get_config
# Description: Get configuration of an existing service in Examind.
# Parameters:
# - service_type [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: The type of the service.
# - identifier [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Identifier of the new service instance.
# Returns:
#   Description: Object use to configure the instance. If not specified the instance will be configured  a default value.
#   Type: ['OBJECT']
#
#
# ID: examind.reload.fs.config
# Description: Reload the filesystem config.
# Parameters:
# Returns:
#
#
# ID: load_collection
# Description: Load a collection.
# Parameters:
# - id [{'type': ['STRING'], 'subtype': 'collection-id'}]
#   Description: The collection Id to load
# - spatial_extent [{'title': 'Bounding Box', 'description': 'A bounding box is a list of 4 numbers (west, south, east, north) and an associated CRS.', 'properties': {'east': {'description': 'East (upper right corner)', 'type': 'number'}, 'south': {'description': 'South (lower left corner)', 'type': 'number'}, 'crs': {'description': 'The coordinate reference system in which the coordinates are given.', 'type': 'any', 'default': 'EPSG:4326'}, 'north': {'description': 'North (upper right corner)', 'type': 'number'}, 'west': {'description': 'West (lower left corner)', 'type': 'number'}}, 'required': ['west', 'south', 'east', 'north'], 'type': ['OBJECT'], 'subtype': 'bounding-box'}, {'title': 'No filter', 'description': "Don't filter spatially", 'type': ['NULL']}]
#   Description: Limits the data to load from the collection to the specified bounding box.
#
# Set this parameter to `null` to set no limit for the spatial extent. Be careful with this when loading large datasets!
# - temporal_extent [{'title': 'Temporal extent', 'description': 'Temporal extent to load.', 'items': {'anyOf': [{'type': 'string', 'subtype': 'date-time', 'format': 'date-time'}, {'type': 'string', 'subtype': 'date', 'format': 'date'}, {'type': 'NULL'}]}, 'type': ['ARRAY'], 'subtype': 'temporal-interval'}, {'title': 'No filter', 'description': "Don't filter temporally.", 'type': ['NULL']}]
#   Description: Limits the data to load from the collection to the specified left-closed temporal interval. The interval has to be specified as an array with exactly two elements:
#
# 1. The first element is the start of the temporal interval. The specified instance in time is **included** in the interval.
# 2. The second element is the end of the temporal interval. The specified instance in time is **excluded** from the interval.
#
# Set this parameter to `null` to set no limit for the temporal extent. Be careful with this when loading large datasets!
# - bands [{'title': 'Bands identifier to select', 'description': 'Bands to select using their index (you can use information in the collection to match this index to the content of the band)', 'items': {'type': 'number', 'subtype': 'band'}, 'type': ['ARRAY']}, {'title': 'No filter', 'description': "Don't filter bands. All bands are included in the data cube.", 'type': ['NULL']}]
#   Description: Only adds the specified band into the data cube.
#
# This parameter expects an array of integers, where each integer specifies a band by its band index (1-based). For example, to load the first and third band of a collection, set this parameter to `[1, 3]`.
#
# Set this parameter to `null` to load all bands of the collection. Be careful with this when loading large datasets!
# Returns:
#   Description: A GridCoverage containing the data of the loaded collection. This objct is a data cube that will be use for further processing.
#   Type: ['OBJECT']
#
#
# ID: examind.sta.downloader
# Description: Download sensor data.
# Parameters:
# - sta_url [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: sensor things API service Url.
# - thing_id [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Thing identifier(s).
# - observed_property [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Observed property identifier(s).
# - boundary [{'title': 'Bounding Box', 'description': 'A bounding box is a list of 4 numbers (west, south, east, north) and an associated CRS.', 'properties': {'east': {'description': 'East (upper right corner)', 'type': 'number'}, 'south': {'description': 'South (lower left corner)', 'type': 'number'}, 'crs': {'description': 'The coordinate reference system in which the coordinates are given.', 'type': 'any', 'default': 'EPSG:4326'}, 'north': {'description': 'North (upper right corner)', 'type': 'number'}, 'west': {'description': 'West (lower left corner)', 'type': 'number'}}, 'required': ['west', 'south', 'east', 'north'], 'type': ['OBJECT'], 'subtype': 'bounding-box'}, {'title': 'No filter', 'description': "Don't filter spatially", 'type': ['NULL']}]
#   Description: Boundary.
# - output_format [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Output format.
# - compress [{'type': ['BOOLEAN'], 'subtype': 'Boolean'}]
#   Description: Compress flag.
# Returns:
#   Description: File output.
#   Type: ['OBJECT']
#
#
# ID: examind.provider.delete
# Description: Delete a provider from Examind.
# Parameters:
# - provider_id [{'type': ['INTEGER'], 'subtype': 'Integer'}]
#   Description: Identifier of the provider.
# - only_hidden_data [{'type': ['BOOLEAN'], 'subtype': 'Boolean'}]
#   Description: Flag to remove provider containing only hidden (non-pyramid) data.
# Returns:
#
#
# ID: examind.service.restart
# Description: Restart an instance for the specified service instance. Or all service instances if identifier is not specified.
# Parameters:
# - service_type [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: The type of the service.
# - identifier [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Identifier of the new service instance.
# Returns:
#
#
# ID: examind.coverage.load
# Description: Load a coverage resource from a WCS service (serviceID)
# Parameters:
# - serviceId [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: The service Id where the coverage is
# - coverageLayerId [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: The coverage layer Id to load
# - spatial_extent [{'title': 'Bounding Box', 'description': 'A bounding box is a list of 4 numbers (west, south, east, north) and an associated CRS.', 'properties': {'east': {'description': 'East (upper right corner)', 'type': 'number'}, 'south': {'description': 'South (lower left corner)', 'type': 'number'}, 'crs': {'description': 'The coordinate reference system in which the coordinates are given.', 'type': 'any', 'default': 'EPSG:4326'}, 'north': {'description': 'North (upper right corner)', 'type': 'number'}, 'west': {'description': 'West (lower left corner)', 'type': 'number'}}, 'required': ['west', 'south', 'east', 'north'], 'type': ['OBJECT'], 'subtype': 'bounding-box'}, {'title': 'No filter', 'description': "Don't filter spatially", 'type': ['NULL']}]
#   Description: The bounding box / spatial extent to load
# - temporal_extent [{'title': 'Temporal extent', 'description': 'Temporal extent to load.', 'items': {'anyOf': [{'type': 'string', 'subtype': 'date-time', 'format': 'date-time'}, {'type': 'string', 'subtype': 'date', 'format': 'date'}, {'type': 'NULL'}]}, 'type': ['ARRAY'], 'subtype': 'temporal-interval'}, {'title': 'No filter', 'description': "Don't filter temporally.", 'type': ['NULL']}]
#   Description: The temporal extent to load (2 values (interval))
# - bands [{'title': 'Bands identifier to select', 'description': 'Bands to select using their index (you can use information in the collection to match this index to the content of the band)', 'items': {'type': 'number', 'subtype': 'band'}, 'type': ['ARRAY']}, {'title': 'No filter', 'description': "Don't filter bands. All bands are included in the data cube.", 'type': ['NULL']}]
#   Description: Bands to load
# Returns:
#   Description: The GridCoverage loaded
#   Type: ['OBJECT']
#
#
# ID: examind.sosHarvester.prepare
# Description: prepare SOS data Harvesting.
# Parameters:
# - data_folder [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Folder containing the files to harvest.
# - user_name [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: FTP user name.
# - user_password [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: FTP user password
# - observation_type [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Observation type ("Timeserie", "Trajectory" or "Profile")
# - generated_task_name [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: generated task name
# - format [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Data format (mime type) of the file to insert
# - result_column [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Column containing result values (used with csv-flat)
# - observed_properties_columns [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Columns containing the observed property (used with csv-flat)
# - type_column [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: type column
# - separator [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: separator
# - quote_character [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: quote character
# Returns:
#   Description: The assigned identifier of the deployed process.
#   Type: ['STRING']
#
#
# ID: examind.service.start
# Description: Start a new instance for the specified service identifier.
# Parameters:
# - service_type [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: The type of the service.
# - identifier [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Identifier of the new service instance.
# Returns:
#
#
# ID: examind.chain.clear
# Description: Clear all registered docker process in examind
# Parameters:
# - single process [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: single single
# Returns:
#
#
# ID: save_result
# Description: Save a coverage in a specified format
# Parameters:
# - coverage [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.coverage.grid.GridCoverage'}]
#   Description: The coverage to save
# - format [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Format used to save the coverage
# Returns:
#   Description: Result
#   Type: []
#
#
# ID: examind.test.multithread.failure
# Description: Test multiple thread failure.
# Parameters:
# - throw.ex [{'type': ['BOOLEAN'], 'subtype': 'Boolean'}]
#   Description: Runtime exception are throw by child tread.
# Returns:
#
#
# ID: examind.test.nb_band
# Description: Count the number of band in a gridCoverageResource.
# Parameters:
# - coverage [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.storage.GridCoverageResource'}]
#   Description: The input coverage.
# Returns:
#   Description: The number of band in the coverage.
#   Type: ['INTEGER']
#
#
# ID: examind.metadata.add
# Description: Add a metadata to a CSW service.
# Parameters:
# - service_identifier [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: the identifier of the CSW servicer.
# - metadata [{'type': []}]
#   Description: The metadata to add to CSW.
# - metadata-id [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: The metadata identifier.
# - refresh [{'type': ['BOOLEAN'], 'subtype': 'Boolean'}]
#   Description: If set this flag the CSW will be refreshed.
# Returns:
#
#
# ID: examind.service.stop
# Description: Stop the instance for the specified service instance.
# Parameters:
# - service_type [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: The type of the service.
# - identifier [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Identifier of the new service instance.
# Returns:
#
#
# ID: examind.metadata.remove
# Description: Remove a metadata to a CSW service.
# Parameters:
# - service_identifier [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: the identifier of the CSW service.
# - metadata-id [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: The metadata identifier.
# Returns:
#
#
# ID: examind.datasource.remove
# Description: Remove a or multiple datasource by their id or path.
# Parameters:
# - datasource.id [{'type': ['INTEGER'], 'subtype': 'Integer'}]
#   Description: the identifier of the datasource to remove.
# - datasource.path [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: the path of the datasources to remove.
# Returns:
#
#
# ID: examind.service.rename
# Description: rename a new ogc service in constellation.
# Parameters:
# - service_type [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: The type of the service.
# - identifier [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Identifier of the new service instance.
# - newName [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: new name of the service instance.
# Returns:
#
#
# ID: examind.sensor.remove
# Description: Remove one or all the sensors.
# Parameters:
# - sensor_identifier [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: the identifier of the sensor.
# - delete_data [{'type': ['BOOLEAN'], 'subtype': 'Boolean'}]
#   Description: If set this flag the associated data wil be removed.
# Returns:
#
#
# ID: examind.test.echo
# Description: Echo different input to output.
# Parameters:
# - literal.input [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Literal input.
# - boundingbox.input [{'title': 'Bounding Box', 'description': 'A bounding box is a list of 4 numbers (west, south, east, north) and an associated CRS.', 'properties': {'east': {'description': 'East (upper right corner)', 'type': 'number'}, 'south': {'description': 'South (lower left corner)', 'type': 'number'}, 'crs': {'description': 'The coordinate reference system in which the coordinates are given.', 'type': 'any', 'default': 'EPSG:4326'}, 'north': {'description': 'North (upper right corner)', 'type': 'number'}, 'west': {'description': 'West (lower left corner)', 'type': 'number'}}, 'required': ['west', 'south', 'east', 'north'], 'type': ['OBJECT'], 'subtype': 'bounding-box'}, {'title': 'No filter', 'description': "Don't filter spatially", 'type': ['NULL']}]
#   Description: Boundingbox input.
# - complex.input [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Complex input.
# Returns:
#   Description: Literal output.
#   Type: ['STRING']
#
#
# ID: examind.featureset.to.geojson
# Description: Return a GeoJSON view of a featureSet.
# Parameters:
# - featureset [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.storage.FeatureSet'}]
#   Description: The input featureSet.
# Returns:
#   Description: The GeoJSON view of the featureSet.
#   Type: ['STRING']
#
#
# ID: examind.test.param.dependency
# Description: Param used to test parameter value dependencies.
# Parameters:
# - country [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Country.
# - city [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: City.
# - district [{'type': ['INTEGER'], 'subtype': 'Integer'}]
#   Description: District.
# - boundary [{'title': 'Bounding Box', 'description': 'A bounding box is a list of 4 numbers (west, south, east, north) and an associated CRS.', 'properties': {'east': {'description': 'East (upper right corner)', 'type': 'number'}, 'south': {'description': 'South (lower left corner)', 'type': 'number'}, 'crs': {'description': 'The coordinate reference system in which the coordinates are given.', 'type': 'any', 'default': 'EPSG:4326'}, 'north': {'description': 'North (upper right corner)', 'type': 'number'}, 'west': {'description': 'West (lower left corner)', 'type': 'number'}}, 'required': ['west', 'south', 'east', 'north'], 'type': ['OBJECT'], 'subtype': 'bounding-box'}, {'title': 'No filter', 'description': "Don't filter spatially", 'type': ['NULL']}]
#   Description: Boundary.
# Returns:
#
#
# ID: examind.test.path
# Description: Test the UI file handling.
# Parameters:
# - path.input [{'type': []}]
#   Description: Path input.
# - boundingbox.input [{'type': ['OBJECT'], 'subtype': 'java.io.File'}]
#   Description: Boundingbox input.
# Returns:
#   Description: Path output.
#   Type: []
#
#
# ID: examind.sosHarvester.clean
# Description: Harvests SOS data.
# Parameters:
# - data folder [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: data folder
# - Observation Type [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Observation Type
# - Store Id [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Store Id
# Returns:
#
#
# ID: examind.coverage.loadFromResource
# Description: Load a coverage resource
# Parameters:
# - coverage [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.storage.GridCoverageResource'}]
#   Description: The coverage to load
# Returns:
#   Description: The GridCoverage loaded
#   Type: ['OBJECT']
#
#
# ID: administration.yamlReader
# Description: Read a Yaml to create a process.
# Parameters:
# - yaml path [{'type': []}]
#   Description: yaml path
# Returns:
#   Description: JSON value of the process output
#   Type: ['STRING']
#
#
# ID: mapfile.mapfileToSLD
# Description: Transform a mapfile in sld
# Parameters:
# - source [{'type': ['OBJECT'], 'subtype': 'java.io.File'}]
#   Description: mapfile
# - target [{'type': ['OBJECT'], 'subtype': 'java.io.File'}]
#   Description: output sld
# Returns:
#
#
# ID: geotoolkit.math:min
# Description: Return the min double from an array of double
# Parameters:
# - set [{'type': ['ARRAY'], 'subtype': 'Real'}]
#   Description: Set of double
# Returns:
#   Description: Min double result
#   Type: ['NUMBER']
#
#
# ID: geotoolkit.coverage:computeVolume
# Description: Create a pyramid / mosaic from the givencoverage. Created tiles are stored in the given Coverage store.
# Parameters:
# - GridCoverageResource [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.storage.GridCoverageResource'}]
#   Description: GridCoverageResource which contain Digital Elevation model to compute bulk.
# - Geometry [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geomatry which represent area where compute bulk.
# - Geometry CRS [{'type': ['OBJECT'], 'subtype': 'CRS'}]
#   Description: Define in which CRS geometry is defined.
# - D E M band index. [{'type': ['INTEGER'], 'subtype': 'Integer'}]
#   Description: D E M band index which will be use to compute volume.
# - Minimum Altitude ceiling value. [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: Minimal altitude value. Volume is computed between ground formed by geometry at this value and Maximum altitude value.
# - Maximum Altitude ceiling value. [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: Maximal altitude value. Volume is computed between ground formed by geometry at minimum ceiling value and its value.
# Returns:
#   Description: Result of volume computing.
#   Type: ['NUMBER']
#
#
# ID: geotoolkit.math:power
# Description: Return first double raised to the power of the second (first^second).
# Parameters:
# - first [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: first number
# - second [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: second number
# Returns:
#   Description: power result
#   Type: ['NUMBER']
#
#
# ID: geotoolkit.coverage:reformat
# Description: Change the sample type of a coverage.
# Parameters:
# - coverage [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.coverage.grid.GridCoverage'}]
#   Description: Coverage to reformat
# - datatype [{'type': ['INTEGER'], 'subtype': 'Integer'}]
#   Description: Sample primitive type
# Returns:
#   Description: Result reformated coverage
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.jts:touches
# Description: Returns true if this geometry(geom1) touches the specified geometry(geom2).
# Parameters:
# - geom1 [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS source
# - geom2 [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS
# Returns:
#   Description: Touches result
#   Type: ['BOOLEAN']
#
#
# ID: geotoolkit.arrays.createGridCoverageValues
# Description: Create an Array of GridCoverage with maximum 10 different inputs
# Parameters:
# - first [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.coverage.grid.GridCoverage'}]
#   Description: First value
# - second [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.coverage.grid.GridCoverage'}]
#   Description: Second value
# - third [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.coverage.grid.GridCoverage'}]
#   Description: Third value
# - fourth [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.coverage.grid.GridCoverage'}]
#   Description: Fourth value
# - fifth [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.coverage.grid.GridCoverage'}]
#   Description: Fifth value
# - sixth [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.coverage.grid.GridCoverage'}]
#   Description: Sixth value
# - seventh [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.coverage.grid.GridCoverage'}]
#   Description: Seventh value
# - eighth [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.coverage.grid.GridCoverage'}]
#   Description: Eighth value
# - ninth [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.coverage.grid.GridCoverage'}]
#   Description: Ninth value
# - tenth [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.coverage.grid.GridCoverage'}]
#   Description: Tenth value
# Returns:
#   Description: Set of double
#   Type: ['ARRAY']
#
#
# ID: geotoolkit.coverage:straighten
# Description: Straighten a coverage, make a coverage with regular scale and no rotation.
# Parameters:
# - coverage_in [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.coverage.grid.GridCoverage'}]
#   Description: Input coverage
# Returns:
#   Description: Output coverage
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.coverage:math:multiplyWithValue
# Description: Mulitply a Coverage with a single value
# Parameters:
# - coverage [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.coverage.grid.GridCoverage'}]
#   Description: Input coverage
# - value [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: Input value
# Returns:
#   Description: Result as a coverage
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.jts:union
# Description: Computes a union Geometry between the source geometry (geom1) and the other (geom2).
# Parameters:
# - geom1 [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS source
# - geom2 [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS
# Returns:
#   Description: The union geometry result
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.math:max
# Description: Return the max double from an array of double
# Parameters:
# - set [{'type': ['ARRAY'], 'subtype': 'Real'}]
#   Description: Set of double
# Returns:
#   Description: max double result
#   Type: ['NUMBER']
#
#
# ID: geotoolkit.jts:intersectionSurface
# Description: Computes an intersection Geometry between the source geometry (geom1) and the other (geom2), and calculates the intersection surface.
# Parameters:
# - geom1 [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS source
# - geom2 [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS
# Returns:
#   Description: The intersection surface result
#   Type: ['NUMBER']
#
#
# ID: geotoolkit.vector:maxlimit
# Description: Limit a FeatureCollection returns to a maximum
# Parameters:
# - feature_in [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.storage.FeatureSet'}]
#   Description: Input FeatureCollection
# - max_in [{'type': ['INTEGER'], 'subtype': 'Integer'}]
#   Description: Number maximum of Feature
# Returns:
#   Description: Output FeatureFeatureCollection
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.coverage:mathcalc
# Description: Perform a mathematic equation on input datas.
# Parameters:
# - inCoverages [{'type': ['ARRAY'], 'subtype': 'org.apache.sis.coverage.grid.GridCoverage'}]
#   Description: Input coverages
# - inFormula [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Formula
# - inMapping [{'type': ['ARRAY'], 'subtype': 'CharacterString'}]
#   Description: Coverage to formula variable
# - inResultCoverage [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.storage.WritableGridCoverageResource'}]
#   Description: Output writable coverage
# Returns:
#
#
# ID: geotoolkit.image:reformat
# Description: Change the sample type of a image.
# Parameters:
# - image [{'type': ['OBJECT'], 'subtype': 'java.awt.image.RenderedImage'}]
#   Description: Image to reformat
# - datatype [{'type': ['INTEGER'], 'subtype': 'Integer'}]
#   Description: Sample primitive type
# Returns:
#   Description: Result reformated image
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.vector:startoffset
# Description: Start FeatureSet iteration at given offset
# Parameters:
# - feature_in [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.storage.FeatureSet'}]
#   Description: Input FeatureCollection
# - offset_in [{'type': ['INTEGER'], 'subtype': 'Integer'}]
#   Description: Start offset iteration on the FeatureCollection
# Returns:
#   Description: Output FeatureFeatureCollection
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.math:median
# Description: Return the median of an array of double
# Parameters:
# - set [{'type': ['ARRAY'], 'subtype': 'Real'}]
#   Description: Set of double
# Returns:
#   Description: Median result
#   Type: ['NUMBER']
#
#
# ID: geotoolkit.string:concat
# Description: Concatenate a string with a sufix and/or a prefix.
# Parameters:
# - prefix [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Prefix to add to the string value
# - suffix [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Suffix to add to the string value
# - value [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: The string value
# Returns:
#   Description: The concatened string
#   Type: ['STRING']
#
#
# ID: geotoolkit.vector:difference
# Description: Return the result FeatureCollection of Difference process
# Parameters:
# - feature_in [{'type': []}]
#   Description: Input FeatureCollection
# - feature_diff [{'type': []}]
#   Description: Input FeatureCollection used for compute the difference
# Returns:
#   Description: Output FeatureFeatureCollection
#   Type: []
#
#
# ID: geotoolkit.math:acos
# Description: Return arc cosinus of a double.
# Parameters:
# - first [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: first number
# Returns:
#   Description: Arc cosinus result
#   Type: ['NUMBER']
#
#
# ID: geotoolkit.arrays.createDoubleValues
# Description: Create an Array of double with maximum 10 different inputs
# Parameters:
# - first [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: First value
# - second [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: Second value
# - third [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: Third value
# - fourth [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: Fourth value
# - fifth [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: Fifth value
# - sixth [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: Sixth value
# - seventh [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: Seventh value
# - eighth [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: Eighth value
# - ninth [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: Ninth value
# - tenth [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: Tenth value
# Returns:
#   Description: Set of double
#   Type: ['ARRAY']
#
#
# ID: geotoolkit.vector:clipGeometry
# Description: Clip a FeatureCollection with a geometry and return a resulting FeatureCollection
# Parameters:
# - feature_in [{'type': []}]
#   Description: Input FeatureCollection
# - clip_geometry_in [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Input clip geometry
# Returns:
#   Description: Output FeatureFeatureCollection
#   Type: []
#
#
# ID: geotoolkit.jts:covers
# Description: Returns true if this geometry source (geom1) covers the specified geometry (geom2).
# Parameters:
# - geom1 [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS source
# - geom2 [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS
# Returns:
#   Description: Covered by result
#   Type: ['BOOLEAN']
#
#
# ID: geotoolkit.jts:equals2d
# Description: Return true if source geometry (geom1) is equals to the other geometry (geom2) .
# Parameters:
# - geom1 [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS source
# - geom2 [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS
# - tolerance [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: Toleranec used
# Returns:
#   Description: Equals2d result
#   Type: ['BOOLEAN']
#
#
# ID: geotoolkit.math:log
# Description: Return the natural logarithm of a double
# Parameters:
# - first [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: first number
# Returns:
#   Description: Logarithm result
#   Type: ['NUMBER']
#
#
# ID: geotoolkit.jts:difference
# Description: Computes a difference Geometry between the source geometry (geom1) and the other (geom2).
# Parameters:
# - geom1 [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS source
# - geom2 [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS
# Returns:
#   Description: The difference geometry result
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.io:delete
# Description: Delete the inputed file or folder.
# Parameters:
# - path [{'type': ['OBJECT'], 'subtype': 'java.lang.Object'}]
#   Description: The path(URI,URL,File,String) to object to delete
# Returns:
#   Description: Success of the deletion
#   Type: ['BOOLEAN']
#
#
# ID: geotoolkit.math:sum
# Description: Return the sum of an array of double
# Parameters:
# - set [{'type': ['ARRAY'], 'subtype': 'Real'}]
#   Description: Set of double
# Returns:
#   Description: Sum result
#   Type: ['NUMBER']
#
#
# ID: geotoolkit.io:createTempFolder
# Description: Create a temporary folder.
# Parameters:
# - prefix [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: The folder prefix
# Returns:
#   Description: Created temp folder
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.jts:crosses
# Description:  Returns true if this geometry source (geom1) crosses the specified geometry (geom2).
# Parameters:
# - geom1 [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS source
# - geom2 [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS
# Returns:
#   Description: Covered by result
#   Type: ['BOOLEAN']
#
#
# ID: geotoolkit.vector:clusterhull
# Description: Return the cluster hull based on FeatureCollection geometries
# Parameters:
# - feature_set_in [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.storage.FeatureSet'}]
#   Description: Input Feature Set
# - tolerance_value [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: Measure of tolerance used
# - smoothing_epsilon [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: Tolerance of the smoothing algorithm
# - tolerance_unit [{'type': ['OBJECT'], 'subtype': 'javax.measure.Unit'}]
#   Description: Unit of tolerance used
# Returns:
#   Description: Cluster hull feature set
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.vector:convexhull
# Description: Return the convex hull based on FeatureCollection geometries
# Parameters:
# - feature_in [{'type': []}]
#   Description: Inpute Feature
# - geometry_name [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Geometry used
# Returns:
#   Description: Convex Hull geometry
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.math:atan
# Description: Return arc tangent of a double.
# Parameters:
# - first [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: first number
# Returns:
#   Description: Arc tangent result
#   Type: ['NUMBER']
#
#
# ID: geotoolkit.vector:nearest
# Description: Return the nearest Feature(s) in a FeatureCollection with the inputGeometry
# Parameters:
# - feature_in [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.storage.FeatureSet'}]
#   Description: Input FeatureCollection
# - geometry_in [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Input geometry
# Returns:
#   Description: Output FeatureFeatureCollection
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.jts:envelope
# Description: Returns this Geometry bounding box.
# Parameters:
# - geom [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS
# Returns:
#   Description: Envelope geometry result
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.image:bandselect
# Description: Select bands in a image.
# Parameters:
# - image [{'type': ['OBJECT'], 'subtype': 'java.awt.image.RenderedImage'}]
#   Description: Image from where to extract bands
# - bands [{'type': ['ARRAY'], 'subtype': 'Integer'}]
#   Description: Indexes of image bands to extract
# Returns:
#   Description: Result image
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.vector:sortby
# Description: Sort a FeatureCollection
# Parameters:
# - feature_in [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.storage.FeatureSet'}]
#   Description: Input FeatureCollection
# - sorter_in [{'type': ['ARRAY'], 'subtype': 'SortProperty'}]
#   Description: Array of SortBy used give the order
# Returns:
#   Description: Output FeatureFeatureCollection
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.jts:centroid
# Description: Return the centroid point of an input JTS geometry
# Parameters:
# - geom [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS
# Returns:
#   Description: Geometry centroid result
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.jts:isEmpty
# Description: Returns true if this geometry source is an empty geometry.
# Parameters:
# - geom [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS source
# Returns:
#   Description: IsEmpty result
#   Type: ['BOOLEAN']
#
#
# ID: geotoolkit.coverage:bandselect
# Description: Select bands in a coverage.
# Parameters:
# - coverage [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.coverage.grid.GridCoverage'}]
#   Description: Coverage from where to extract bands
# - bands [{'type': ['ARRAY'], 'subtype': 'Integer'}]
#   Description: Indexes of coverage bands to extract
# Returns:
#   Description: Result coverage
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.jts:within
# Description: Returns true if this geometry source (geom1) is within the specified geometry (geom2).
# Parameters:
# - geom1 [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS source
# - geom2 [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS
# Returns:
#   Description: Within result
#   Type: ['BOOLEAN']
#
#
# ID: geotoolkit.math:divide
# Description: Divide two double (first/second).
# Parameters:
# - first [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: first number
# - second [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: second number
# Returns:
#   Description: divide result
#   Type: ['NUMBER']
#
#
# ID: geotoolkit.jts:convexHull
# Description: Return the convex hull geometry of the specified geometry.
# Parameters:
# - geom [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS
# Returns:
#   Description: ConvexHull geometry result
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.math:multiply
# Description: Multiply two double .
# Parameters:
# - first [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: first number
# - second [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: second number
# Returns:
#   Description: multiply result
#   Type: ['NUMBER']
#
#
# ID: geotoolkit.vector:reproject
# Description: Return a FeatureCollection re-project into the target CRS
# Parameters:
# - feature_in [{'type': []}]
#   Description: Input FeatureCollection
# - crs_in [{'type': ['OBJECT'], 'subtype': 'CRS'}]
#   Description: The target CRS
# Returns:
#   Description: Output FeatureFeatureCollection
#   Type: []
#
#
# ID: geotoolkit.jts:lenght
# Description: Returns the length of this Geometry.
# Parameters:
# - geom [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS source
# Returns:
#   Description: Length result
#   Type: ['NUMBER']
#
#
# ID: geotoolkit.script:evaluate
# Description: Evaluate expression given in parameter w
# Parameters:
# - language [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: language
# - expression [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Script
# - variables [{'type': ['OBJECT'], 'subtype': 'java.lang.Object'}]
#   Description: Map of binding script variable
# - behavior [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Behavior of the process. Could be 'EXCEPTION' or 'RESULT'
# Returns:
#   Description: Result of the expression
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.vector:diffGeometry
# Description: Compute difference between a FeatureCollection and a geometry. Return a FeatureCollection.
# Parameters:
# - feature_in [{'type': []}]
#   Description: Input FeatureCollection
# - diff_geometry_in [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Inpute clip geometry
# Returns:
#   Description: Output FeatureFeatureCollection
#   Type: []
#
#
# ID: geotoolkit.coverage:math:sumWithValue
# Description: Sum a Coverage with a single value
# Parameters:
# - coverage [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.coverage.grid.GridCoverage'}]
#   Description: Input coverage
# - value [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: Input value
# Returns:
#   Description: Result as a coverage
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.jts:boundary
# Description: Return boundarty geometry of an input JTS geometry
# Parameters:
# - geom [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS
# Returns:
#   Description: Boundary geometry result
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.math:sin
# Description: Returns the trigonometric sine of an angle in double.
# Parameters:
# - first [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: first number
# Returns:
#   Description: sinus result
#   Type: ['NUMBER']
#
#
# ID: geotoolkit.coverage:bandcombine
# Description: Combine multiple coverage.
# Parameters:
# - coverages [{'type': ['ARRAY'], 'subtype': 'org.apache.sis.coverage.grid.GridCoverage'}]
#   Description: Coverages to merge
# Returns:
#   Description: Result combined coverage
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.math:avg
# Description: Return the average value of an array of double
# Parameters:
# - set [{'type': ['ARRAY'], 'subtype': 'Real'}]
#   Description: Set of double
# Returns:
#   Description: Average double result
#   Type: ['NUMBER']
#
#
# ID: geotoolkit.vector:union
# Description: Return the result FeatureCollection of Union process
# Parameters:
# - feature_in [{'type': []}]
#   Description: Input FeatureCollection
# - feature_union [{'type': []}]
#   Description: Input FeatureCollection used for Union process
# - input_geometry_name [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Input geometry property name
# - union_geometry_name [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Union geometry property name
# Returns:
#   Description: Output FeatureFeatureCollection
#   Type: []
#
#
# ID: geotoolkit.math:asin
# Description: Return arc sinus of a double.
# Parameters:
# - first [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: first number
# Returns:
#   Description: Arc sinus result
#   Type: ['NUMBER']
#
#
# ID: geotoolkit.math:floor
# Description: Returns the nearest lower or equals integer (in double) to the argument double.
# Parameters:
# - first [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: first number
# Returns:
#   Description: Floor result
#   Type: ['NUMBER']
#
#
# ID: geotoolkit.vector:merge
# Description: Merge many FeatureCollection in one. The fist FeatureCollection found in the input Collection have his FeatureType preserved. The others will be adapted to this one.
# Parameters:
# - features_in [{'type': ['ARRAY'], 'subtype': 'org.geotoolkit.storage.feature.FeatureCollection'}]
#   Description: Inpute array of FeatureCollection
# Returns:
#   Description: The merged FeatureCollection
#   Type: []
#
#
# ID: geotoolkit.vector:retype
# Description: Limit a FeatureCollection returns to a maximum
# Parameters:
# - feature_in [{'type': []}]
#   Description: Input FeatureCollection
# - mask_in [{'type': ['OBJECT'], 'subtype': 'FeatureType'}]
#   Description: FeatureType used to as a mask to retype the FeatureCollection
# Returns:
#   Description: Output FeatureFeatureCollection
#   Type: []
#
#
# ID: geotoolkit.jts:coveredBy
# Description: Returns true if this geometry source (geom1) is covered by the specified geometry (geom2).
# Parameters:
# - geom1 [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS source
# - geom2 [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS
# Returns:
#   Description: Covered by result
#   Type: ['BOOLEAN']
#
#
# ID: geotoolkit.vector:regroup
# Description: Return a Featrue Collection generated by the Regroup processEach different value of the given attribute name return a Feature.
# Parameters:
# - feature_in [{'type': []}]
#   Description: Input FeatureCollection
# - regroup_attribute [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Attribute name used for the regroup process
# - geometry_name [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Geometry property name
# Returns:
#   Description: Output FeatureFeatureCollection
#   Type: []
#
#
# ID: geotoolkit.jts:intersects
# Description: Returns true if this geometry source (geom1) intersects the specified geometry (geom2).
# Parameters:
# - geom1 [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS source
# - geom2 [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS
# Returns:
#   Description: Intersects result
#   Type: ['BOOLEAN']
#
#
# ID: geotoolkit.io:createTempFile
# Description: Create a temporary file.
# Parameters:
# - prefix [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: The file prefix
# - postfix [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: The file postfix
# - delete [{'type': ['BOOLEAN'], 'subtype': 'Boolean'}]
#   Description: Delete file on application end
# Returns:
#   Description: Created temp file
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.math:ceil
# Description: Returns the nearest upper or equals integer (in double) to the argument double.
# Parameters:
# - first [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: first number
# Returns:
#   Description: Ceil result
#   Type: ['NUMBER']
#
#
# ID: geotoolkit.math:round
# Description: Returns the closest long to the argument. The result is rounded to an integer by adding 1/2, taking the floor of the result, and casting the result to type long.
# Parameters:
# - first [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: first number
# Returns:
#   Description: Round result
#   Type: ['NUMBER']
#
#
# ID: geotoolkit.jts:contain
# Description: Return true if source geometry (geom1) contains the specified geometry(geom2).
# Parameters:
# - geom1 [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS source
# - geom2 [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS
# Returns:
#   Description: Contain result
#   Type: ['BOOLEAN']
#
#
# ID: geotoolkit.math:substract
# Description: Substract two double (first - second).
# Parameters:
# - first [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: first number
# - second [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: second number
# Returns:
#   Description: substraction result
#   Type: ['NUMBER']
#
#
# ID: geotoolkit.vector:spatialjoin
# Description: Return the target FeatureCollection with source FeatureCollection attributes.The link between target and source depend of method used (Intersect or Nearest)
# Parameters:
# - feature_in [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.storage.FeatureSet'}]
#   Description: Input FeatureCollection
# - feature_target [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.storage.FeatureSet'}]
#   Description: Target Features
# - intersect [{'type': ['BOOLEAN'], 'subtype': 'Boolean'}]
#   Description: Method used, intersect or nearest
# Returns:
#   Description: Output FeatureFeatureCollection
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.coverage:math:sum
# Description: Sum single specified band of each coverage in a result coverage
# Parameters:
# - first [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.coverage.grid.GridCoverage'}]
#   Description: First Coverage (A in A+B)
# - second [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.coverage.grid.GridCoverage'}]
#   Description: Second Coverage (B in A+B)
# Returns:
#   Description: Result as a coverage
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.vector:clip
# Description: Return the result FeatureCollection of clipping
# Parameters:
# - feature_in [{'type': []}]
#   Description: Input FeatureCollection
# - feature_clip [{'type': []}]
#   Description: Inpute FeatureCollection for clipping
# Returns:
#   Description: Output FeatureFeatureCollection
#   Type: []
#
#
# ID: geotoolkit.jts:intersection
# Description: Computes a intersection Geometry between the source geometry (geom1) and the other (geom2).
# Parameters:
# - geom1 [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS source
# - geom2 [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS
# Returns:
#   Description: The intersection geometry result
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.math:absolute
# Description: Return the absolute value of a double.
# Parameters:
# - first [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: first number
# Returns:
#   Description: absolute result
#   Type: ['NUMBER']
#
#
# ID: geotoolkit.jts:overlaps
# Description: Returns true if this geometry (geom1) overlaps the specified geometry (geom2).
# Parameters:
# - geom1 [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS source
# - geom2 [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS
# Returns:
#   Description: Overlaps result
#   Type: ['BOOLEAN']
#
#
# ID: geotoolkit.vector:intersect
# Description: Return all Feature witch intersect the input geometry
# Parameters:
# - feature_in [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.storage.FeatureSet'}]
#   Description: Input FeatureCollection
# - geometry_in [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Input geometry used to compute the intersection
# Returns:
#   Description: Output FeatureFeatureCollection
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.math:add
# Description: Adds two double.
# Parameters:
# - first [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: first number
# - second [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: second number
# Returns:
#   Description: addition result
#   Type: ['NUMBER']
#
#
# ID: geotoolkit.math:tan
# Description: Returns the trigonometric tangent of an angle in double.
# Parameters:
# - first [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: first number
# Returns:
#   Description: Tangent result
#   Type: ['NUMBER']
#
#
# ID: geotoolkit.coverage:merge
# Description: Merge multiple coverages.
# Parameters:
# - coverages [{'type': ['ARRAY'], 'subtype': 'org.apache.sis.coverage.grid.GridCoverage'}]
#   Description: Coverages to merge
# - envelope [{'title': 'Bounding Box', 'description': 'A bounding box is a list of 4 numbers (west, south, east, north) and an associated CRS.', 'properties': {'east': {'description': 'East (upper right corner)', 'type': 'number'}, 'south': {'description': 'South (lower left corner)', 'type': 'number'}, 'crs': {'description': 'The coordinate reference system in which the coordinates are given.', 'type': 'any', 'default': 'EPSG:4326'}, 'north': {'description': 'North (upper right corner)', 'type': 'number'}, 'west': {'description': 'West (lower left corner)', 'type': 'number'}}, 'required': ['west', 'south', 'east', 'north'], 'type': ['OBJECT'], 'subtype': 'bounding-box'}]
#   Description: Result coverage envelope
# - resolution [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: Result coverage resolution
# Returns:
#   Description: Result combined coverage
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.math:toRadian
# Description: Converts an angle measured in degrees to an approximately equivalent angle measured in radians.
# Parameters:
# - first [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: first number
# Returns:
#   Description: Radian result
#   Type: ['NUMBER']
#
#
# ID: geotoolkit.io:packFile
# Description: Pack a file list into a compressed archive.
# Parameters:
# - source [{'type': ['ARRAY'], 'subtype': 'java.io.File'}]
#   Description: files to pack
# - target [{'type': ['OBJECT'], 'subtype': 'java.io.File'}]
#   Description: zip file destination
# Returns:
#   Description: packed file
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.jts:area
# Description: Return the area of a JTS geometry
# Parameters:
# - geom [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS
# Returns:
#   Description: Area result
#   Type: ['NUMBER']
#
#
# ID: geotoolkit.vector:filter
# Description: Apply a filter to a FeatureCollection
# Parameters:
# - feature_in [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.storage.FeatureSet'}]
#   Description: Input FeatureCollection
# - filter_in [{'type': ['OBJECT'], 'subtype': 'Filter'}]
#   Description: Filter
# Returns:
#   Description: Output FeatureFeatureCollection
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.coverage:CoverageToVector
# Description: Transform a coverage in features by agregating pixels as geometries when they are in the same range.
# Parameters:
# - coverage [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.coverage.grid.GridCoverage'}]
#   Description: Coverage to process.
# - ranges [{'type': ['ARRAY'], 'subtype': 'org.apache.sis.measure.NumberRange'}]
#   Description: Ranges to regroup.
# - band [{'type': ['INTEGER'], 'subtype': 'Integer'}]
#   Description: Band to transform
# Returns:
#   Description: Result of vectorisation.
#   Type: ['ARRAY']
#
#
# ID: geotoolkit.io:unpackFile
# Description: Unpack a compressed archive in a given directory, supports : zip,jar,tar,tar.gz .
# Parameters:
# - source [{'type': ['OBJECT'], 'subtype': 'java.lang.Object'}]
#   Description: url,uri,file to read from
# - target [{'type': ['OBJECT'], 'subtype': 'java.lang.Object'}]
#   Description: url,uri,file destination
# Returns:
#   Description: unpacked files
#   Type: ['ARRAY']
#
#
# ID: geotoolkit.coverage:math:divide
# Description: Divide single specified band of each coverage in a result coverage
# Parameters:
# - first [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.coverage.grid.GridCoverage'}]
#   Description: First Coverage (A in A/B)
# - second [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.coverage.grid.GridCoverage'}]
#   Description: Second Coverage (B in A/B)
# Returns:
#   Description: Result as a coverage
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.coverage:math:substract
# Description: Substract single specified band of each coverage in a result coverage
# Parameters:
# - first [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.coverage.grid.GridCoverage'}]
#   Description: First Coverage (A in A-B)
# - second [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.coverage.grid.GridCoverage'}]
#   Description: Second Coverage (B in A-B)
# Returns:
#   Description: Result as a coverage
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.jts:buffer
# Description: Apply JTS buffer to a geometry.
# Parameters:
# - geom [{'type': ['OBJECT'], 'subtype': 'org.locationtech.jts.geom.Geometry'}]
#   Description: Geometry JTS
# - distance [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: Distance used to make buffer.
# - segments [{'type': ['INTEGER'], 'subtype': 'Integer'}]
#   Description: Number of segments used to represent a quadrant of a circle.
# - endstyle [{'type': ['INTEGER'], 'subtype': 'Integer'}]
#   Description: The end cap style used. 1 -> Round, 2 -> Flat, 3 -> Square.
# Returns:
#   Description: Buffered geometry result
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.math:atan2
# Description: Returns the angle theta from the conversion of rectangular coordinates (x, y) to polar coordinates (r, theta). This method computes the phase theta by computing an arc tangent of y/x in the range of -pi to pi..
# Parameters:
# - first [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: x abscissa coordinate
# - second [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: y ordinate coordinate
# Returns:
#   Description: theta angle result
#   Type: ['NUMBER']
#
#
# ID: geotoolkit.math:toDegree
# Description: Converts an angle measured in radians to an approximately equivalent angle measured in degrees.
# Parameters:
# - first [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: first number
# Returns:
#   Description: Degree result
#   Type: ['NUMBER']
#
#
# ID: geotoolkit.math:cos
# Description: Returns the trigonometric cosinus of an angle in double.
# Parameters:
# - first [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: first number
# Returns:
#   Description: cosinus result
#   Type: ['NUMBER']
#
#
# ID: geotoolkit.referencing:createdb
# Description: Create an epsg database.
# Parameters:
# - dburl [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Database JDBC URL.
# - user [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Database user.
# - password [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Database password.
# Returns:
#
#
# ID: geotoolkit.vector:intersection
# Description: Return a new FeatureCollection where each Feature is create from an intersection Geometry
# Parameters:
# - feature_in [{'type': []}]
#   Description: Input FeatureCollection
# - feature_inter [{'type': []}]
#   Description: Inpute FeatureCollection for the intersection
# - geometry_name [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Geometry property name
# Returns:
#   Description: Output FeatureFeatureCollection
#   Type: []
#
#
# ID: geotoolkit.coverage:math:divideWithValue
# Description: Divide a Coverage with a single value
# Parameters:
# - coverage [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.coverage.grid.GridCoverage'}]
#   Description: Input coverage
# - value [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: Input value
# Returns:
#   Description: Result as a coverage
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.coverage:math:substractWithValue
# Description: Substract a Coverage with a single value
# Parameters:
# - coverage [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.coverage.grid.GridCoverage'}]
#   Description: Input coverage
# - value [{'type': ['NUMBER'], 'subtype': 'Real'}]
#   Description: Input value
# Returns:
#   Description: Result as a coverage
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.coverage:math:multiply
# Description: Multiply single specified band of each coverage in a result coverage
# Parameters:
# - first [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.coverage.grid.GridCoverage'}]
#   Description: First Coverage (A in A*B)
# - second [{'type': ['OBJECT'], 'subtype': 'org.apache.sis.coverage.grid.GridCoverage'}]
#   Description: Second Coverage (B in A*B)
# Returns:
#   Description: Result as a coverage
#   Type: ['OBJECT']
#
#
# ID: geotoolkit.vector:affinetransform
# Description: Apply an affine transformation in Features geometries
# Parameters:
# - feature_in [{'type': []}]
#   Description: Input FeatureCollection
# - transform_in [{'type': ['OBJECT'], 'subtype': 'java.awt.geom.AffineTransform'}]
#   Description: The affine transformation to apply on Features geometries
# Returns:
#   Description: Output FeatureFeatureCollection
#   Type: []
#
#
# ID: examind-dynamic.temp-openeo-test-execution-fd210ca6-b743-496b-b4f8-95d082022c95
# Description: Computes the Enhanced Vegetation Index (EVI). It is computed with the following formula: `2.5 * (NIR - RED) / (1 + NIR + 6*RED + -7.5*BLUE)`.
# Parameters:
# Returns:
#   Description: Computed EVI.
#   Type: ['OBJECT']
#
#
# ID: examind-dynamic.temp-openeo-test-execution-b13e8087-35bb-41a0-b53e-3112f278e413
# Description: Computes the Enhanced Vegetation Index (EVI). It is computed with the following formula: `2.5 * (NIR - RED) / (1 + NIR + 6*RED + -7.5*BLUE)`.
# Parameters:
# Returns:
#   Description: Computed EVI.
#   Type: ['OBJECT']
#
#
# ID: examind-dynamic.temp-openeo-test-execution-fa30eb43-5ec4-4eaa-95a8-11aac43a0a0b
# Description: Computes the Enhanced Vegetation Index (EVI). It is computed with the following formula: `2.5 * (NIR - RED) / (1 + NIR + 6*RED + -7.5*BLUE)`.
# Parameters:
# Returns:
#   Description: Computed EVI.
#   Type: ['OBJECT']
#
#
# ID: examind-dynamic.temp-openeo-test-execution-a64fe01f-39d9-4370-a4cd-ddf03d4d5bac
# Description: Computes the Enhanced Vegetation Index (EVI). It is computed with the following formula: `2.5 * (NIR - RED) / (1 + NIR + 6*RED + -7.5*BLUE)`.
# Parameters:
# Returns:
#   Description: Computed EVI.
#   Type: ['OBJECT']
#
#
# ID: examind-dynamic.openeo-evi-sentinel
# Description: Computes the Enhanced Vegetation Index (EVI). It is computed with the following formula: `2.5 * (NIR - RED) / (1 + NIR + 6*RED + 7.5*BLUE)`.
# Parameters:
# - dataId [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Sentinel-2 data id
# - bbox [{'type': ['OBJECT'], 'subtype': 'java.lang.Object'}]
#   Description: Spatial extent
# - bands [{'title': 'Bands identifier to select', 'description': 'Bands to select using their index (you can use information in the collection to match this index to the content of the band)', 'items': {'type': 'number', 'subtype': 'band'}, 'type': ['ARRAY']}]
#   Description: Bands to load
# - temporal [{'type': ['ARRAY'], 'subtype': 'CharacterString'}]
#   Description: Temporal extent
# Returns:
#   Description: Computed EVI.
#   Type: ['OBJECT']
#
#
# ID: examind-dynamic.temp-openeo-test-execution
# Description: Computes the Enhanced Vegetation Index (EVI). It is computed with the following formula: `2.5 * (NIR - RED) / (1 + NIR + 6*RED + -7.5*BLUE)`.
# Parameters:
# Returns:
#   Description: Computed EVI.
#   Type: ['OBJECT']
#
#
# ID: examind-dynamic.temp-openeo-null
# Description: temp-openeo-null
# Parameters:
# Returns:
#   Description: output
#   Type: ['OBJECT']
#
#
# ID: examind-dynamic.temp-openeo-test-execution-bb2e7e00-0419-490f-9496-eec23a56fb3e
# Description: Computes the Enhanced Vegetation Index (EVI). It is computed with the following formula: `2.5 * (NIR - RED) / (1 + NIR + 6*RED + -7.5*BLUE)`.
# Parameters:
# Returns:
#   Description: Computed EVI.
#   Type: ['OBJECT']
#
#
# ID: examind-dynamic.temp-openeo-test-execution-3e4bc1ab-a19d-4575-a6f2-96de96a48a2b
# Description: Computes the Enhanced Vegetation Index (EVI). It is computed with the following formula: `2.5 * (NIR - RED) / (1 + NIR + 6*RED + -7.5*BLUE)`.
# Parameters:
# Returns:
#   Description: Computed EVI.
#   Type: ['OBJECT']

# %% [markdown]
# You can also get a list of processes that have been added by a user.
#
# *(If you follow this tutorial in order, you shouldn't find anything for the moment.
# If you come back to this request later, you'll see the process we're going to create next.)*

# %%
URL = SERVER_IP + "/examind/WS/openeo/" + OPENEO_SERVICE_ID + "/process_graphs"

r = requests.get(url = URL)

data = r.json()

# If you want to show the raw json output
# print(json.dumps(data, indent=2))

# Iterate over each process in the data
for process in data['processes']:
    print(f"ID: {process['id']}")

    print(f"Description: {process['description']}")

    print("Parameters:")
    for parameter in process['parameters']:
        print(f"- {parameter['name']} {parameter['schema']}")
        print(f"  Description: {parameter['description']}")
        if 'subtype' in parameter['schema'] and parameter['schema']['subtype'] is not None:
            print(f"  Subtype: {parameter['schema']['subtype']}")

    print("Returns:")
    if process['returns']['schema'] is not None:
        print(f"  Description: {process['returns']['description']}")
        print(f"  Type: {process['returns']['schema']['type']}")
        if 'subtype' in process['returns']['schema'] and process['returns']['schema']['subtype'] is not None:
            print(f"  Subtype: {process['returns']['schema']['subtype']}")

    print("\n")
# Out:
# ID: examind-dynamic.openeo-evi-sentinel
# Description: Computes the Enhanced Vegetation Index (EVI). It is computed with the following formula: `2.5 * (NIR - RED) / (1 + NIR + 6*RED + 7.5*BLUE)`.
# Parameters:
# - dataId [{'type': ['STRING'], 'subtype': 'CharacterString'}]
#   Description: Sentinel-2 data id
# - bbox [{'type': ['OBJECT'], 'subtype': 'java.lang.Object'}]
#   Description: Spatial extent
# - bands [{'title': 'Bands identifier to select', 'description': 'Bands to select using their index (you can use information in the collection to match this index to the content of the band)', 'items': {'type': 'number', 'subtype': 'band'}, 'type': ['ARRAY']}]
#   Description: Bands to load
# - temporal [{'type': ['ARRAY'], 'subtype': 'CharacterString'}]
#   Description: Temporal extent
# Returns:
#   Description: Computed EVI.
#   Type: ['OBJECT']

# %% [markdown]
# ### 2 - Create your own process
#
# This step should eventually work via openEO web Editor (https://github.com/Open-EO/openeo-web-editor), but for the moment our implementation is not compatible (nor is it compatible with openEO clients) because some of the paths to the APIs are not standard (the way the API works, however, is compliant).
#
# For the moment, we're going to create an EVI (Enhanced Vegetation Index) process by ourselves, directly via an http request !

# %%
# Set Json of my EVI-Sentinel process

data = {
    'id': 'evi-sentinel',
    'summary': 'Enhanced Vegetation Index',
    'description': 'Computes the Enhanced Vegetation Index (EVI). It is computed with the following formula: `2.5 * (NIR - RED) / (1 + NIR + 6*RED + 7.5*BLUE)`.',
    'parameters': [
        {
            'name': 'dataId',
            'description': 'Sentinel-2 data id',
            'schema': [{
                'type': 'String'
            }]
        },
        {
            'name': 'bbox',
            'description': 'Spatial extent',
            'schema': [{
                'type': 'Object'
            }]
        },
        {
            'name': 'temporal',
            'description': 'Temporal extent',
            'schema': [{
                'type': 'Array',
                'subtype': 'String'
            }]
        },
        {
            'name': 'bands',
            'description': 'Bands to load',
            'schema': [{
                'type': 'Array',
                'subtype': 'String'
            }]
        }
    ],
    'returns': {
        'description': 'Computed EVI.',
        'schema': {
            'type': 'object'
        }
    },
    'process_graph': {
        'load': {
            'process_id': 'load_collection',
            'arguments': {
                'id': {
                    'from_parameter': 'dataId'
                },
                'spatial_extent': {
                    'from_parameter': 'bbox'
                },
                'temporal_extent': {
                    'from_parameter': 'temporal'
                },
                'bands': {
                    'from_parameter': 'bands'
                }
            }
        },
        'bs3': {
            'process_id': 'geotoolkit.coverage:bandselect',
            'arguments': {
                'coverage': {
                    'from_node': 'load'
                },
                'bands': [
                    0
                ]
            }
        },
        'bs4': {
            'process_id': 'geotoolkit.coverage:bandselect',
            'arguments': {
                'coverage': {
                    'from_node': 'load'
                },
                'bands': [
                    1
                ]
            }
        },
        'bs8': {
            'process_id': 'geotoolkit.coverage:bandselect',
            'arguments': {
                'coverage': {
                    'from_node': 'load'
                },
                'bands': [
                    2
                ]
            }
        },
        'sub': {
            'process_id': 'geotoolkit.coverage:math:substract',
            'arguments': {
                'first': {
                    'from_node': 'bs8'
                },
                'second': {
                    'from_node': 'bs3'
                }
            }
        },
        'p1': {
            'process_id': 'geotoolkit.coverage:math:multiplyWithValue',
            'arguments': {
                'value': 6.0,
                'coverage': {
                    'from_node': 'bs3'
                }
            }
        },
        'p2': {
            'process_id': 'geotoolkit.coverage:math:multiplyWithValue',
            'arguments': {
                'value': 7.5,
                'coverage': {
                    'from_node': 'bs4'
                }
            }
        },
        'sumCoverages1': {
            'process_id': 'geotoolkit.coverage:math:sum',
            'arguments': {
                'first': {
                    'from_node': 'bs8'
                },
                'second': {
                    'from_node': 'p1'
                }
            }
        },
        'sumCoverages2': {
            'process_id': 'geotoolkit.coverage:math:sum',
            'arguments': {
                'first': {
                    'from_node': 'sumCoverages1'
                },
                'second': {
                    'from_node': 'p2'
                }
            }
        },
        'sum': {
            'process_id': 'geotoolkit.coverage:math:sumWithValue',
            'arguments': {
                'coverage': {
                    'from_node': 'sumCoverages2'
                },
                'value': 1.0
            }
        },
        'div': {
            'process_id': 'geotoolkit.coverage:math:divide',
            'arguments': {
                'first': {
                    'from_node': 'sub'
                },
                'second': {
                    'from_node': 'sum'
                }
            }
        },
        'p3': {
            'process_id': 'geotoolkit.coverage:math:multiplyWithValue',
            'arguments': {
                'value': 2.5,
                'coverage': {
                    'from_node': 'div'
                }
            }
        },
        'save': {
            'process_id': 'save_result',
            'arguments': {
                'format': 'GTIFF',
                'data': {
                    'from_node': 'p3'
                }
            },
            'result': True
        }
    }
}

# %% [markdown]
# You can check if your process is valid with `/validation` endpoint

# %%
URL = SERVER_IP + "/examind/WS/openeo/" + OPENEO_SERVICE_ID + "/validation"

headers = {'Content-Type': 'application/json', 'Accept': '*/*'}

r = requests.post(url=URL, data=json.dumps(data), headers=headers)

print(f"Status {r.status_code}")
print(json.dumps(r.json(), indent=2))
# Out:
# Status 200
# {
#   "errors": []
# }

# %% [markdown]
# Then, if it's valid, you can put your process on the server with `/process_graphs/{id_process}` endpoint

# %%
URL = SERVER_IP + "/examind/WS/openeo/" + OPENEO_SERVICE_ID + "/process_graphs/evi-sentinel"

headers = {'Content-Type': 'application/json', 'Accept': '*/*'}

r = requests.put(url=URL, data=json.dumps(data), headers=headers)

print(f"Status {r.status_code}")
if r.text and r.text is not None:
    print(json.dumps(r.json(), indent=2))
# Out:
# Status 200

# %% [markdown]
# **NOTE 1**
#
# The process id you created is not exactly the same as the one specified. The server adds the prefix `openeo-` before your process id for internal management reasons.
# So, for example, `evi-sentinel` becomes `openeo-evi-sentinel`.
#
# ---
#
# **NOTE 2**
#
# If the process id already exist because you have already uploaded this process, you can delete it with the following request :

# %%
URL = SERVER_IP + "/examind/WS/openeo/" + OPENEO_SERVICE_ID + "/process_graphs/evi-sentinel"

headers = {'Content-Type': 'application/json', 'Accept': '*/*'}

r = requests.delete(url=URL, headers=headers)

print(f"Status {r.status_code}")
# Out:
# Status 200

# %% [markdown]
# ### 3 - Execute your process (**sync way**)
#
# You can run an openEo process in two ways :
# - **synchronised** (the result arrives directly, you only have to make one request)
# - **asynchronous** (you launch the process, and you have to run another request to see the status and the result).
#
# Here, I will show you how to execute our *evi-sentinel* process with one request (sync).
#
# We will use the `/result` endpoint
#
# ---
#
# **NOTE**
#
# In the case of synchronous execution, the user must create a process_graph passed in the request. A previously created process_graph cannot be queried directly. A workaround is to create a process_graph which takes only one process, the one created before (openeo-evi-sentinel).
#
# ---
#
# **INFO**
#
# **1. How to import my data in Examind ?**
#
# I've written a short tutorial to import your data in Examind, using the sentinel-2 data example. Here is the link : [import_data.md](./import_data.md)
#
# **2. How do you retrieve the id of the data you want to use ?**
#
# I've written a short tutorial to find the data id, using the sentinel-2 data example. Here is the link : [retrieve_data_id.md](./retrieve_data_id.md)

# %%
# Set JSON execution process_graph

exec_data = {
    "process": {
        "id": "evi-execution",
        "summary": "Enhanced Vegetation Index",
        "description": "Computes the Enhanced Vegetation Index (EVI). It is computed with the following formula: `2.5 * (NIR - RED) / (1 + NIR + 6*RED + -7.5*BLUE)`.",
        "parameters": [],
        "returns": {
            "description": "Computed EVI.",
            "schema": {
                "type": "object"
            }
        },
        "process_graph": {
            "load": {
                "process_id": "examind-dynamic.openeo-evi-sentinel",
                "arguments": {
                    "dataId": "sentinel_evi_bands",
                    "bbox": {
                        "west": 3.87,
                        "east": 4.5,
                        "north": 43.85,
                        "south": 43.56,
                        "crs": "urn:ogc:def:crs:OGC:1.3:CRS84"
                    },
                    "temporal": ["none"],
                    "bands": [0, 2, 4]
                },
                "result": "true"
            }
        }
    }
}

# %%
URL = SERVER_IP + "/examind/WS/openeo/" + OPENEO_SERVICE_ID + "/result"

headers = {'Content-Type': 'application/json', 'Accept': '*/*'}

username = "admin"
password = "admin"

r = requests.post(url=URL, data=json.dumps(exec_data), headers=headers, auth=HTTPBasicAuth(username, password))

print(f"Status {r.status_code}")
print(r.text)

file_path = "./file.tiff"
os.makedirs(os.path.dirname(file_path), exist_ok=True)
with open(file_path, "wb") as f:
    f.write(r.content)

with rasterio.open(BytesIO(r.content)) as src:
    image_data = src.read()
    
cmap = plt.cm.colors.LinearSegmentedColormap.from_list('white_to_green', ['white', 'green'])
plt.imshow(image_data.transpose([1, 2, 0]), cmap=cmap)
plt.colorbar()
plt.show()
# Out:
# Status 200
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
source_data_graph = {
    "process": {
        "id": "test-execution",
        "summary": "Enhanced Vegetation Index",
        "description": "Computes the Enhanced Vegetation Index (EVI). It is computed with the following formula: `2.5 * (NIR - RED) / (1 + NIR + 6*RED + -7.5*BLUE)`.",
        "parameters": [],
        "returns": {
            "description": "Computed EVI.",
            "schema": {
                "type": "object"
            }
        },
        "process_graph": {
            "load": {
                "process_id": "load_collection",
                "arguments": {
                    "id": "1",
                    "spatial_extent": {
                        "west": 3.87,
                        "east": 4.5,
                        "north": 43.85,
                        "south": 43.56
                    },
                    "temporal_extent": ["none"],
                    "bands": [0, 2, 4]
                },
            },
            "save": {
                "process_id": "save_result",
                "arguments": {
                    "format": "GTIFF",
                    "data": {
                        "from_node": "load"
                    }
                },
                "result": True
            }
        }
    }
}

# %%
URL = SERVER_IP + "/examind/WS/openeo/" + OPENEO_SERVICE_ID + "/result"

headers = {'Content-Type': 'application/json', 'Accept': '*/*'}

username = "admin"
password = "admin"

r = requests.post(url=URL, data=json.dumps(source_data_graph), headers=headers, auth=HTTPBasicAuth(username, password))

print(f"Status {r.status_code}")
print(r.text)

file_path = "./source.tiff"
os.makedirs(os.path.dirname(file_path), exist_ok=True)
with open(file_path, "wb") as f:
    f.write(r.content)

with rasterio.open(BytesIO(r.content)) as src:
    image_data = src.read()

plt.imshow(image_data.transpose([1, 2, 0]))
plt.colorbar()
plt.show()
# Out:
# Status 200
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..2.5843].
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ### 4 - Execute your process (**async way**)
#
# Here, I will show you how to execute our *evi-sentinel* process the async way.
#
# - We will use the `/jobs` endpoint to create process job and get all jobs created *(4.1 & 4.2)*
# - We will use the `/jobs/{job_id}/results` to execute a job and get its results *(4.3 & 4.4)*
# - We will use the `/jobs/{job_id}` to delete a job *(4.5)*

# %% [markdown]
# #### 4.1 - Create a process job
# `POST` - `/jobs`

# %%
URL = SERVER_IP + "/examind/WS/openeo/process/WPS/jobs"

headers = {'Content-Type': 'application/json', 'Accept': '*/*'}

r = requests.post(url=URL, data=json.dumps(exec_data), headers=headers)

print(f"Status {r.status_code}")
if r.text and r.text is not None:
    if r.status_code == 200 or r.status_code == 201:
        print(f"Job ID : {r.text}")
        JOB_ID = r.text
    else:
        print(r.text)
# Out:
# Status 201
# Job ID : 7b04fa92-da3e-4ef1-be42-956693a18724

# %%
# If you want to set another JOB_ID :
JOB_ID = "<job_id>"

# %% [markdown]
# #### 4.2 - Get jobs created and status
# `GET` - `/jobs`

# %%
URL = SERVER_IP + "/examind/WS/openeo/process/WPS/jobs"

headers = {'Content-Type': 'application/json', 'Accept': '*/*'}

r = requests.get(url=URL, headers=headers)

print(f"Status {r.status_code}")
if r.text and r.text is not None:
    print(json.dumps(r.json(), indent=2))
# Out:
# Status 200
# {
#   "jobs": [
#     {
#       "id": "7b04fa92-da3e-4ef1-be42-956693a18724",
#       "status": "created",
#       "created": "2024-12-09T08:55:03",
#       "progress": 0.0,
#       "costs": 0.0,
#       "budget": 0.0
#     }
#   ],
#   "links": []
# }

# %% [markdown]
# #### 4.3 - Run a job
# `POST` - `/jobs/{job_id}/results`

# %%
URL = SERVER_IP + f"/examind/WS/openeo/process/WPS/jobs/{JOB_ID}/results"

headers = {'Content-Type': 'application/json', 'Accept': '*/*'}

r = requests.post(url=URL, headers=headers)

print(f"Status {r.status_code}")
if r.text and r.text is not None:
    print(r.text)
# Out:
# Status 202
# created

# %% [markdown]
# #### 4.4 - Get job result
# `GET` - `/jobs/{job_id}/results`

# %%
URL = SERVER_IP + f"/examind/WS/openeo/process/WPS/jobs/{JOB_ID}/results"

headers = {'Content-Type': 'application/json', 'Accept': '*/*'}

r = requests.get(url=URL, headers=headers)

print(f"Status {r.status_code}")
if r.text and r.text is not None:
    print(r.text)

with rasterio.open(BytesIO(r.content)) as src:
    image_data = src.read()

cmap = plt.cm.colors.LinearSegmentedColormap.from_list('white_to_green', ['white', 'green'])
plt.imshow(image_data.transpose([1, 2, 0]), cmap=cmap)
plt.colorbar()
plt.show()
# Out:
# Status 200
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# #### 4.5 - Delete job
# `DELETE` - `/jobs/{job_id}`

# %%
# For this request, you need to be authenticated !
URL = SERVER_IP + f"/examind/API/auth/login"
body = {"username":"admin","password":"admin"}

r = requests.post(url=URL, data=json.dumps(body), headers=headers)

##################################################

URL = SERVER_IP + f"/examind/WS/openeo/process/WPS/jobs/{JOB_ID}"

headers = {'Content-Type': 'application/json', 'Accept': '*/*'}

r = requests.delete(url=URL, headers=headers, cookies=r.cookies)

print(f"Status {r.status_code}")
if r.text and r.text is not None:
    print(r.text)
# Out:
# Status 500
# {"id":"44d2f1b1-fef9-411a-a033-c7d4c4b41a3a","code":"ServerError","message":"Info : There is no job registrered in the service with the id:b01d459b-2e87-4aa4-8f7c-e3edcd9bc15c","links":[]}
